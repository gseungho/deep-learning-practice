# %% [markdown]
# # 주제 : 사진에서 사람영역만 구분해보기
# --------------
# ## 실습 가이드
#     1. 데이터를 다운로드하여 Colab에 불러옵니다.
#     2. 필요한 라이브러리는 모두 코드로 작성되어 있습니다.
#     3. 코드는 위에서부터 아래로 순서대로 실행합니다.
#     4. 전체 문제 구성은 좌측 첫 번째 아이콘을 통해 확인할 수 있습니다.
#
# ## 데이터 소개
#     - 이번 주제의 데이터는 protrait 데이터로 유명한 PFCN dataset을 이용합니다.
#   ![PFCN dataset](https://www.researchgate.net/profile/Dawei_Li49/publication/334417334/figure/fig4/AS:832930272276492@1575597460956/Sample-images-from-the-PFCN-dataset.jpg)
#
#      위의 이미지는 다음과 같은 것을 보여줍니다.
#     - 800x600의 사람 portrait 이미지
#      - ?????.png
#     - 사람 영역에 대한 흑백 portrait 이미지
#      - ?????_matte.png
#     - pfcn_original
#      - 원본 800x600 이미지들
#     - pfcn_small
#      - colab용 100x75 이미지들
#
#
#
# - 데이터 출처:
#  - [PFCN dataset](https://1drv.ms/u/s!ApwdOxIIFBH19Ts5EuFd9gVJrKTo)
#  - [pfcn_small](https://drive.google.com/file/d/1_q37TRIFwtwhmSeLu_4h3SkFHrDSjeyl/view?usp=sharing)
#  - [pfcn_original](https://onedrive.live.com/?authkey=%21ADkS4V32BUmspOg&cid=F5111408123B1D9C&id=F5111408123B1D9C%2115035&parId=F5111408123B1D9C%2115033&action=locate)
#
# ## 최종 목표
#
#     - 작게 줄인 PFCN 데이터를 이용하여 사람 영역 추출
#     - 코렙에 구글 drive 연동
#     - 큰 사진을 작게 줄이기
#     - 이미지에 대한 오토인코더식 접근 방법
#
# - 출제자 : 손근영 강사
# ---

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense
from keras.models import Sequential

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from IPython.display import Image

warnings.filterwarnings('ignore')
# %matplotlib inline

SEED = 34

# %% [markdown]
# ## Step 1. 도입전 기본 처리

# %% [markdown]
# ### 문제 1. 구글 drive와 colab 연동하기

# %%
# https://onedrive.live.com/?authkey=%21ADkS4V32BUmspOg&cid=F5111408123B1D9C&id=F5111408123B1D9C%2115035&parId=F5111408123B1D9C%2115033&action=locate

from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
# !ls -al /gdrive/'My Drive'/'Colab Notebooks'/dataset/pfcn_original/testing
# Out:
# total 186325
# -rw------- 1 root root   26653 Oct  7  2016 00001_matte.png
# -rw------- 1 root root  753417 Oct  7  2016 00001.png
# -rw------- 1 root root   34216 Oct  7  2016 00002_matte.png
# -rw------- 1 root root  604936 Oct  7  2016 00002.png
# -rw------- 1 root root   35363 Oct  7  2016 00003_matte.png
# -rw------- 1 root root  435284 Oct  7  2016 00003.png
# -rw------- 1 root root   28328 Oct  7  2016 00004_matte.png
# -rw------- 1 root root  524318 Oct  7  2016 00004.png
# -rw------- 1 root root   25115 Oct  7  2016 00005_matte.png
# -rw------- 1 root root  540187 Oct  7  2016 00005.png
# -rw------- 1 root root   31603 Oct  7  2016 00006_matte.png
# -rw------- 1 root root  638427 Oct  7  2016 00006.png
# -rw------- 1 root root   26514 Oct  7  2016 00007_matte.png
# -rw------- 1 root root  655077 Oct  7  2016 00007.png
# -rw------- 1 root root   39624 Oct  7  2016 00008_matte.png
# -rw------- 1 root root  628124 Oct  7  2016 00008.png
# -rw------- 1 root root   57820 Oct  7  2016 00009_matte.png
# -rw------- 1 root root  679471 Oct  7  2016 00009.png
# -rw------- 1 root root   32265 Oct  7  2016 00010_matte.png
# -rw------- 1 root root  557970 Oct  7  2016 00010.png
# -rw------- 1 root root   38379 Oct  7  2016 00011_matte.png
# -rw------- 1 root root  379412 Oct  7  2016 00011.png
# -rw------- 1 root root   20269 Oct  7  2016 00012_matte.png
# -rw------- 1 root root  761756 Oct  7  2016 00012.png
# -rw------- 1 root root   39359 Oct  7  2016 00013_matte.png
# -rw------- 1 root root  646821 Oct  7  2016 00013.png
# -rw------- 1 root root   28077 Oct  7  2016 00014_matte.png
# -rw------- 1 root root  464003 Oct  7  2016 00014.png
# -rw------- 1 root root   32580 Oct  7  2016 00015_matte.png
# -rw------- 1 root root  441870 Oct  7  2016 00015.png
# -rw------- 1 root root   38446 Oct  7  2016 00016_matte.png
# -rw------- 1 root root  429587 Oct  7  2016 00016.png
# -rw------- 1 root root   42726 Oct  7  2016 00017_matte.png
# -rw------- 1 root root  745605 Oct  7  2016 00017.png
# -rw------- 1 root root   24390 Oct  7  2016 00018_matte.png
# -rw------- 1 root root  547359 Oct  7  2016 00018.png
# -rw------- 1 root root   29989 Oct  7  2016 00019_matte.png
# -rw------- 1 root root  633758 Oct  7  2016 00019.png
# -rw------- 1 root root   31263 Oct  7  2016 00020_matte.png
# -rw------- 1 root root  476458 Oct  7  2016 00020.png
# -rw------- 1 root root   27503 Oct  7  2016 00021_matte.png
# -rw------- 1 root root  577624 Oct  7  2016 00021.png
# -rw------- 1 root root   23004 Oct  7  2016 00022_matte.png
# -rw------- 1 root root  447274 Oct  7  2016 00022.png
# -rw------- 1 root root   29802 Oct  7  2016 00023_matte.png
# -rw------- 1 root root  492436 Oct  7  2016 00023.png
# -rw------- 1 root root   32991 Oct  7  2016 00024_matte.png
# -rw------- 1 root root  545456 Oct  7  2016 00024.png
# -rw------- 1 root root   31110 Oct  7  2016 00025_matte.png
# -rw------- 1 root root  608076 Oct  7  2016 00025.png
# -rw------- 1 root root   41673 Oct  7  2016 00026_matte.png
# -rw------- 1 root root  705137 Oct  7  2016 00026.png
# -rw------- 1 root root   32096 Oct  7  2016 00027_matte.png
# -rw------- 1 root root  645617 Oct  7  2016 00027.png
# -rw------- 1 root root   32219 Oct  7  2016 00028_matte.png
# -rw------- 1 root root  606461 Oct  7  2016 00028.png
# -rw------- 1 root root   45482 Oct  7  2016 00029_matte.png
# -rw------- 1 root root  494901 Oct  7  2016 00029.png
# -rw------- 1 root root   30412 Oct  7  2016 00030_matte.png
# -rw------- 1 root root  634398 Oct  7  2016 00030.png
# -rw------- 1 root root   31266 Oct  7  2016 00031_matte.png
# -rw------- 1 root root  901032 Oct  7  2016 00031.png
# -rw------- 1 root root   31491 Oct  7  2016 00032_matte.png
# -rw------- 1 root root  624173 Oct  7  2016 00032.png
# -rw------- 1 root root   29427 Oct  7  2016 00033_matte.png
# -rw------- 1 root root  311626 Oct  7  2016 00033.png
# -rw------- 1 root root   40774 Oct  7  2016 00034_matte.png
# -rw------- 1 root root  717204 Oct  7  2016 00034.png
# -rw------- 1 root root   29399 Oct  7  2016 00035_matte.png
# -rw------- 1 root root  602447 Oct  7  2016 00035.png
# -rw------- 1 root root   14225 Oct  7  2016 00036_matte.png
# -rw------- 1 root root  762827 Oct  7  2016 00036.png
# -rw------- 1 root root   26703 Oct  7  2016 00037_matte.png
# -rw------- 1 root root  550966 Oct  7  2016 00037.png
# -rw------- 1 root root   23688 Oct  7  2016 00038_matte.png
# -rw------- 1 root root  420617 Oct  7  2016 00038.png
# -rw------- 1 root root   23044 Oct  7  2016 00039_matte.png
# -rw------- 1 root root  642973 Oct  7  2016 00039.png
# -rw------- 1 root root   33521 Oct  7  2016 00040_matte.png
# -rw------- 1 root root  648059 Oct  7  2016 00040.png
# -rw------- 1 root root   21696 Oct  7  2016 00041_matte.png
# -rw------- 1 root root  537309 Oct  7  2016 00041.png
# -rw------- 1 root root   40948 Oct  7  2016 00042_matte.png
# -rw------- 1 root root  638497 Oct  7  2016 00042.png
# -rw------- 1 root root   50001 Oct  7  2016 00043_matte.png
# -rw------- 1 root root  610969 Oct  7  2016 00043.png
# -rw------- 1 root root   30001 Oct  7  2016 00044_matte.png
# -rw------- 1 root root  554991 Oct  7  2016 00044.png
# -rw------- 1 root root   32284 Oct  7  2016 00045_matte.png
# -rw------- 1 root root  784514 Oct  7  2016 00045.png
# -rw------- 1 root root   23648 Oct  7  2016 00046_matte.png
# -rw------- 1 root root  630038 Oct  7  2016 00046.png
# -rw------- 1 root root   27102 Oct  7  2016 00047_matte.png
# -rw------- 1 root root  572647 Oct  7  2016 00047.png
# -rw------- 1 root root   30171 Oct  7  2016 00048_matte.png
# -rw------- 1 root root  586623 Oct  7  2016 00048.png
# -rw------- 1 root root   41990 Oct  7  2016 00049_matte.png
# -rw------- 1 root root  626977 Oct  7  2016 00049.png
# -rw------- 1 root root   34951 Oct  7  2016 00050_matte.png
# -rw------- 1 root root  636561 Oct  7  2016 00050.png
# -rw------- 1 root root   19389 Oct  7  2016 00051_matte.png
# -rw------- 1 root root  720772 Oct  7  2016 00051.png
# -rw------- 1 root root   32343 Oct  7  2016 00052_matte.png
# -rw------- 1 root root  430006 Oct  7  2016 00052.png
# -rw------- 1 root root   31053 Oct  7  2016 00053_matte.png
# -rw------- 1 root root  499054 Oct  7  2016 00053.png
# -rw------- 1 root root   45589 Oct  7  2016 00054_matte.png
# -rw------- 1 root root  447406 Oct  7  2016 00054.png
# -rw------- 1 root root   33644 Oct  7  2016 00055_matte.png
# -rw------- 1 root root  746655 Oct  7  2016 00055.png
# -rw------- 1 root root   33959 Oct  7  2016 00056_matte.png
# -rw------- 1 root root  729899 Oct  7  2016 00056.png
# -rw------- 1 root root   40091 Oct  7  2016 00057_matte.png
# -rw------- 1 root root  865971 Oct  7  2016 00057.png
# -rw------- 1 root root   24976 Oct  7  2016 00058_matte.png
# -rw------- 1 root root  864516 Oct  7  2016 00058.png
# -rw------- 1 root root   24738 Oct  7  2016 00059_matte.png
# -rw------- 1 root root  463409 Oct  7  2016 00059.png
# -rw------- 1 root root   31408 Oct  7  2016 00060_matte.png
# -rw------- 1 root root  603261 Oct  7  2016 00060.png
# -rw------- 1 root root   59940 Oct  7  2016 00061_matte.png
# -rw------- 1 root root  784256 Oct  7  2016 00061.png
# -rw------- 1 root root   31369 Oct  7  2016 00062_matte.png
# -rw------- 1 root root  566323 Oct  7  2016 00062.png
# -rw------- 1 root root   35496 Oct  7  2016 00063_matte.png
# -rw------- 1 root root  431447 Oct  7  2016 00063.png
# -rw------- 1 root root   41147 Oct  7  2016 00064_matte.png
# -rw------- 1 root root  769012 Oct  7  2016 00064.png
# -rw------- 1 root root   31652 Oct  7  2016 00065_matte.png
# -rw------- 1 root root  969390 Oct  7  2016 00065.png
# -rw------- 1 root root   28021 Oct  7  2016 00066_matte.png
# -rw------- 1 root root  613150 Oct  7  2016 00066.png
# -rw------- 1 root root   38557 Oct  7  2016 00067_matte.png
# -rw------- 1 root root  671633 Oct  7  2016 00067.png
# -rw------- 1 root root   32804 Oct  7  2016 00068_matte.png
# -rw------- 1 root root  532692 Oct  7  2016 00068.png
# -rw------- 1 root root   31625 Oct  7  2016 00069_matte.png
# -rw------- 1 root root  601423 Oct  7  2016 00069.png
# -rw------- 1 root root   33340 Oct  7  2016 00070_matte.png
# -rw------- 1 root root  702202 Oct  7  2016 00070.png
# -rw------- 1 root root   33292 Oct  7  2016 00071_matte.png
# -rw------- 1 root root  685508 Oct  7  2016 00071.png
# -rw------- 1 root root   28729 Oct  7  2016 00072_matte.png
# -rw------- 1 root root  497152 Oct  7  2016 00072.png
# -rw------- 1 root root   28970 Oct  7  2016 00073_matte.png
# -rw------- 1 root root  709219 Oct  7  2016 00073.png
# -rw------- 1 root root   21565 Oct  7  2016 00074_matte.png
# -rw------- 1 root root  603503 Oct  7  2016 00074.png
# -rw------- 1 root root   34364 Oct  7  2016 00075_matte.png
# -rw------- 1 root root  617948 Oct  7  2016 00075.png
# -rw------- 1 root root   27683 Oct  7  2016 00076_matte.png
# -rw------- 1 root root  366475 Oct  7  2016 00076.png
# -rw------- 1 root root   26099 Oct  7  2016 00077_matte.png
# -rw------- 1 root root  525402 Oct  7  2016 00077.png
# -rw------- 1 root root   26491 Oct  7  2016 00078_matte.png
# -rw------- 1 root root  577951 Oct  7  2016 00078.png
# -rw------- 1 root root   26713 Oct  7  2016 00079_matte.png
# -rw------- 1 root root  579443 Oct  7  2016 00079.png
# -rw------- 1 root root   24118 Oct  7  2016 00080_matte.png
# -rw------- 1 root root  717387 Oct  7  2016 00080.png
# -rw------- 1 root root   33510 Oct  7  2016 00081_matte.png
# -rw------- 1 root root  553635 Oct  7  2016 00081.png
# -rw------- 1 root root   33725 Oct  7  2016 00082_matte.png
# -rw------- 1 root root  679002 Oct  7  2016 00082.png
# -rw------- 1 root root   33318 Oct  7  2016 00083_matte.png
# -rw------- 1 root root  493167 Oct  7  2016 00083.png
# -rw------- 1 root root   30448 Oct  7  2016 00084_matte.png
# -rw------- 1 root root  427149 Oct  7  2016 00084.png
# -rw------- 1 root root   45299 Oct  7  2016 00085_matte.png
# -rw------- 1 root root  786067 Oct  7  2016 00085.png
# -rw------- 1 root root   28261 Oct  7  2016 00086_matte.png
# -rw------- 1 root root  556408 Oct  7  2016 00086.png
# -rw------- 1 root root   23158 Oct  7  2016 00087_matte.png
# -rw------- 1 root root  641813 Oct  7  2016 00087.png
# -rw------- 1 root root   31697 Oct  7  2016 00088_matte.png
# -rw------- 1 root root  426599 Oct  7  2016 00088.png
# -rw------- 1 root root   14330 Oct  7  2016 00089_matte.png
# -rw------- 1 root root  659184 Oct  7  2016 00089.png
# -rw------- 1 root root   33003 Oct  7  2016 00090_matte.png
# -rw------- 1 root root  656642 Oct  7  2016 00090.png
# -rw------- 1 root root   25699 Oct  7  2016 00091_matte.png
# -rw------- 1 root root  589482 Oct  7  2016 00091.png
# -rw------- 1 root root   47424 Oct  7  2016 00092_matte.png
# -rw------- 1 root root  439907 Oct  7  2016 00092.png
# -rw------- 1 root root   32705 Oct  7  2016 00093_matte.png
# -rw------- 1 root root  747311 Oct  7  2016 00093.png
# -rw------- 1 root root   31493 Oct  7  2016 00094_matte.png
# -rw------- 1 root root  731284 Oct  7  2016 00094.png
# -rw------- 1 root root   20641 Oct  7  2016 00095_matte.png
# -rw------- 1 root root  559106 Oct  7  2016 00095.png
# -rw------- 1 root root   59495 Oct  7  2016 00096_matte.png
# -rw------- 1 root root  594604 Oct  7  2016 00096.png
# -rw------- 1 root root   29540 Oct  7  2016 00097_matte.png
# -rw------- 1 root root  620028 Oct  7  2016 00097.png
# -rw------- 1 root root   30941 Oct  7  2016 00098_matte.png
# -rw------- 1 root root  595124 Oct  7  2016 00098.png
# -rw------- 1 root root   37839 Oct  7  2016 00099_matte.png
# -rw------- 1 root root  884128 Oct  7  2016 00099.png
# -rw------- 1 root root   37359 Oct  7  2016 00100_matte.png
# -rw------- 1 root root  484485 Oct  7  2016 00100.png
# -rw------- 1 root root   26945 Oct  7  2016 00101_matte.png
# -rw------- 1 root root  707341 Oct  7  2016 00101.png
# -rw------- 1 root root   43908 Oct  7  2016 00102_matte.png
# -rw------- 1 root root  542251 Oct  7  2016 00102.png
# -rw------- 1 root root   34364 Oct  7  2016 00103_matte.png
# -rw------- 1 root root  848184 Oct  7  2016 00103.png
# -rw------- 1 root root   29520 Oct  7  2016 00104_matte.png
# -rw------- 1 root root  545517 Oct  7  2016 00104.png
# -rw------- 1 root root   27742 Oct  7  2016 00105_matte.png
# -rw------- 1 root root  632743 Oct  7  2016 00105.png
# -rw------- 1 root root   31261 Oct  7  2016 00106_matte.png
# -rw------- 1 root root  746093 Oct  7  2016 00106.png
# -rw------- 1 root root   35519 Oct  7  2016 00107_matte.png
# -rw------- 1 root root  458282 Oct  7  2016 00107.png
# -rw------- 1 root root   51325 Oct  7  2016 00108_matte.png
# -rw------- 1 root root  543029 Oct  7  2016 00108.png
# -rw------- 1 root root   33139 Oct  7  2016 00109_matte.png
# -rw------- 1 root root 1018171 Oct  7  2016 00109.png
# -rw------- 1 root root   44994 Oct  7  2016 00110_matte.png
# -rw------- 1 root root  727503 Oct  7  2016 00110.png
# -rw------- 1 root root   31035 Oct  7  2016 00111_matte.png
# -rw------- 1 root root  461946 Oct  7  2016 00111.png
# -rw------- 1 root root   30755 Oct  7  2016 00112_matte.png
# -rw------- 1 root root  588147 Oct  7  2016 00112.png
# -rw------- 1 root root   25281 Oct  7  2016 00113_matte.png
# -rw------- 1 root root  397195 Oct  7  2016 00113.png
# -rw------- 1 root root   28326 Oct  7  2016 00114_matte.png
# -rw------- 1 root root  337996 Oct  7  2016 00114.png
# -rw------- 1 root root   45761 Oct  7  2016 00115_matte.png
# -rw------- 1 root root  736098 Oct  7  2016 00115.png
# -rw------- 1 root root   29541 Oct  7  2016 00116_matte.png
# -rw------- 1 root root  562667 Oct  7  2016 00116.png
# -rw------- 1 root root   27376 Oct  7  2016 00117_matte.png
# -rw------- 1 root root  467440 Oct  7  2016 00117.png
# -rw------- 1 root root   30363 Oct  7  2016 00118_matte.png
# -rw------- 1 root root  617738 Oct  7  2016 00118.png
# -rw------- 1 root root   28270 Oct  7  2016 00119_matte.png
# -rw------- 1 root root  467434 Oct  7  2016 00119.png
# -rw------- 1 root root   28523 Oct  7  2016 00120_matte.png
# -rw------- 1 root root  498939 Oct  7  2016 00120.png
# -rw------- 1 root root   33090 Oct  7  2016 00121_matte.png
# -rw------- 1 root root  552375 Oct  7  2016 00121.png
# -rw------- 1 root root   28653 Oct  7  2016 00122_matte.png
# -rw------- 1 root root  743832 Oct  7  2016 00122.png
# -rw------- 1 root root   17883 Oct  7  2016 00123_matte.png
# -rw------- 1 root root  736206 Oct  7  2016 00123.png
# -rw------- 1 root root   29640 Oct  7  2016 00124_matte.png
# -rw------- 1 root root  555223 Oct  7  2016 00124.png
# -rw------- 1 root root   30941 Oct  7  2016 00125_matte.png
# -rw------- 1 root root  592012 Oct  7  2016 00125.png
# -rw------- 1 root root   36649 Oct  7  2016 00126_matte.png
# -rw------- 1 root root  858994 Oct  7  2016 00126.png
# -rw------- 1 root root   34948 Oct  7  2016 00127_matte.png
# -rw------- 1 root root  656681 Oct  7  2016 00127.png
# -rw------- 1 root root   33693 Oct  7  2016 00128_matte.png
# -rw------- 1 root root  975749 Oct  7  2016 00128.png
# -rw------- 1 root root   29262 Oct  7  2016 00129_matte.png
# -rw------- 1 root root  501401 Oct  7  2016 00129.png
# -rw------- 1 root root   25846 Oct  7  2016 00130_matte.png
# -rw------- 1 root root  770479 Oct  7  2016 00130.png
# -rw------- 1 root root   33251 Oct  7  2016 00131_matte.png
# -rw------- 1 root root  675770 Oct  7  2016 00131.png
# -rw------- 1 root root   29985 Oct  7  2016 00132_matte.png
# -rw------- 1 root root  791558 Oct  7  2016 00132.png
# -rw------- 1 root root   30182 Oct  7  2016 00133_matte.png
# -rw------- 1 root root  681012 Oct  7  2016 00133.png
# -rw------- 1 root root   23828 Oct  7  2016 00134_matte.png
# -rw------- 1 root root  431676 Oct  7  2016 00134.png
# -rw------- 1 root root   31620 Oct  7  2016 00135_matte.png
# -rw------- 1 root root  513229 Oct  7  2016 00135.png
# -rw------- 1 root root   28588 Oct  7  2016 00136_matte.png
# -rw------- 1 root root  609718 Oct  7  2016 00136.png
# -rw------- 1 root root   26987 Oct  7  2016 00137_matte.png
# -rw------- 1 root root  523392 Oct  7  2016 00137.png
# -rw------- 1 root root   25916 Oct  7  2016 00138_matte.png
# -rw------- 1 root root  381775 Oct  7  2016 00138.png
# -rw------- 1 root root   31244 Oct  7  2016 00139_matte.png
# -rw------- 1 root root  662584 Oct  7  2016 00139.png
# -rw------- 1 root root   30078 Oct  7  2016 00140_matte.png
# -rw------- 1 root root  556793 Oct  7  2016 00140.png
# -rw------- 1 root root   30555 Oct  7  2016 00141_matte.png
# -rw------- 1 root root  588647 Oct  7  2016 00141.png
# -rw------- 1 root root   29536 Oct  7  2016 00142_matte.png
# -rw------- 1 root root  765101 Oct  7  2016 00142.png
# -rw------- 1 root root   38094 Oct  7  2016 00143_matte.png
# -rw------- 1 root root  828953 Oct  7  2016 00143.png
# -rw------- 1 root root   29035 Oct  7  2016 00144_matte.png
# -rw------- 1 root root  514683 Oct  7  2016 00144.png
# -rw------- 1 root root   30773 Oct  7  2016 00145_matte.png
# -rw------- 1 root root  725326 Oct  7  2016 00145.png
# -rw------- 1 root root   34425 Oct  7  2016 00146_matte.png
# -rw------- 1 root root  653280 Oct  7  2016 00146.png
# -rw------- 1 root root   27942 Oct  7  2016 00147_matte.png
# -rw------- 1 root root  476146 Oct  7  2016 00147.png
# -rw------- 1 root root   23608 Oct  7  2016 00148_matte.png
# -rw------- 1 root root  529230 Oct  7  2016 00148.png
# -rw------- 1 root root   25826 Oct  7  2016 00149_matte.png
# -rw------- 1 root root  757631 Oct  7  2016 00149.png
# -rw------- 1 root root   35782 Oct  7  2016 00150_matte.png
# -rw------- 1 root root  654349 Oct  7  2016 00150.png
# -rw------- 1 root root   26412 Oct  7  2016 00151_matte.png
# -rw------- 1 root root  594475 Oct  7  2016 00151.png
# -rw------- 1 root root   26988 Oct  7  2016 00152_matte.png
# -rw------- 1 root root  698116 Oct  7  2016 00152.png
# -rw------- 1 root root   28752 Oct  7  2016 00153_matte.png
# -rw------- 1 root root  319224 Oct  7  2016 00153.png
# -rw------- 1 root root   30361 Oct  7  2016 00154_matte.png
# -rw------- 1 root root  707311 Oct  7  2016 00154.png
# -rw------- 1 root root   24597 Oct  7  2016 00155_matte.png
# -rw------- 1 root root  519155 Oct  7  2016 00155.png
# -rw------- 1 root root   31746 Oct  7  2016 00156_matte.png
# -rw------- 1 root root  737597 Oct  7  2016 00156.png
# -rw------- 1 root root   31136 Oct  7  2016 00157_matte.png
# -rw------- 1 root root  482965 Oct  7  2016 00157.png
# -rw------- 1 root root   36365 Oct  7  2016 00158_matte.png
# -rw------- 1 root root  718630 Oct  7  2016 00158.png
# -rw------- 1 root root   28556 Oct  7  2016 00159_matte.png
# -rw------- 1 root root  591547 Oct  7  2016 00159.png
# -rw------- 1 root root   28063 Oct  7  2016 00160_matte.png
# -rw------- 1 root root  445317 Oct  7  2016 00160.png
# -rw------- 1 root root   27939 Oct  7  2016 00161_matte.png
# -rw------- 1 root root  756322 Oct  7  2016 00161.png
# -rw------- 1 root root   36804 Oct  7  2016 00162_matte.png
# -rw------- 1 root root  605337 Oct  7  2016 00162.png
# -rw------- 1 root root   31478 Oct  7  2016 00163_matte.png
# -rw------- 1 root root  698096 Oct  7  2016 00163.png
# -rw------- 1 root root   31615 Oct  7  2016 00164_matte.png
# -rw------- 1 root root  759154 Oct  7  2016 00164.png
# -rw------- 1 root root   29395 Oct  7  2016 00165_matte.png
# -rw------- 1 root root  617927 Oct  7  2016 00165.png
# -rw------- 1 root root   33682 Oct  7  2016 00166_matte.png
# -rw------- 1 root root  521272 Oct  7  2016 00166.png
# -rw------- 1 root root   33110 Oct  7  2016 00167_matte.png
# -rw------- 1 root root  700109 Oct  7  2016 00167.png
# -rw------- 1 root root   43643 Oct  7  2016 00168_matte.png
# -rw------- 1 root root  615555 Oct  7  2016 00168.png
# -rw------- 1 root root   34737 Oct  7  2016 00169_matte.png
# -rw------- 1 root root  780643 Oct  7  2016 00169.png
# -rw------- 1 root root   29244 Oct  7  2016 00170_matte.png
# -rw------- 1 root root  450260 Oct  7  2016 00170.png
# -rw------- 1 root root   29346 Oct  7  2016 00171_matte.png
# -rw------- 1 root root  421789 Oct  7  2016 00171.png
# -rw------- 1 root root   37684 Oct  7  2016 00172_matte.png
# -rw------- 1 root root  591547 Oct  7  2016 00172.png
# -rw------- 1 root root   34916 Oct  7  2016 00173_matte.png
# -rw------- 1 root root  657263 Oct  7  2016 00173.png
# -rw------- 1 root root   28749 Oct  7  2016 00174_matte.png
# -rw------- 1 root root  617619 Oct  7  2016 00174.png
# -rw------- 1 root root   24291 Oct  7  2016 00175_matte.png
# -rw------- 1 root root  727260 Oct  7  2016 00175.png
# -rw------- 1 root root   31817 Oct  7  2016 00176_matte.png
# -rw------- 1 root root  699420 Oct  7  2016 00176.png
# -rw------- 1 root root   26947 Oct  7  2016 00177_matte.png
# -rw------- 1 root root  317697 Oct  7  2016 00177.png
# -rw------- 1 root root   27649 Oct  7  2016 00178_matte.png
# -rw------- 1 root root  674841 Oct  7  2016 00178.png
# -rw------- 1 root root   33560 Oct  7  2016 00179_matte.png
# -rw------- 1 root root  587288 Oct  7  2016 00179.png
# -rw------- 1 root root   36218 Oct  7  2016 00180_matte.png
# -rw------- 1 root root  647130 Oct  7  2016 00180.png
# -rw------- 1 root root   30378 Oct  7  2016 00181_matte.png
# -rw------- 1 root root  632325 Oct  7  2016 00181.png
# -rw------- 1 root root   30287 Oct  7  2016 00182_matte.png
# -rw------- 1 root root  690799 Oct  7  2016 00182.png
# -rw------- 1 root root   22415 Oct  7  2016 00183_matte.png
# -rw------- 1 root root  604699 Oct  7  2016 00183.png
# -rw------- 1 root root   33066 Oct  7  2016 00184_matte.png
# -rw------- 1 root root  679221 Oct  7  2016 00184.png
# -rw------- 1 root root   32597 Oct  7  2016 00185_matte.png
# -rw------- 1 root root  659299 Oct  7  2016 00185.png
# -rw------- 1 root root   30953 Oct  7  2016 00186_matte.png
# -rw------- 1 root root  540142 Oct  7  2016 00186.png
# -rw------- 1 root root   25420 Oct  7  2016 00187_matte.png
# -rw------- 1 root root  639751 Oct  7  2016 00187.png
# -rw------- 1 root root   36958 Oct  7  2016 00188_matte.png
# -rw------- 1 root root  861443 Oct  7  2016 00188.png
# -rw------- 1 root root   33564 Oct  7  2016 00189_matte.png
# -rw------- 1 root root  646336 Oct  7  2016 00189.png
# -rw------- 1 root root   31013 Oct  7  2016 00190_matte.png
# -rw------- 1 root root  655693 Oct  7  2016 00190.png
# -rw------- 1 root root   23860 Oct  7  2016 00191_matte.png
# -rw------- 1 root root  528489 Oct  7  2016 00191.png
# -rw------- 1 root root   35175 Oct  7  2016 00192_matte.png
# -rw------- 1 root root  686556 Oct  7  2016 00192.png
# -rw------- 1 root root   28912 Oct  7  2016 00193_matte.png
# -rw------- 1 root root  614075 Oct  7  2016 00193.png
# -rw------- 1 root root   29323 Oct  7  2016 00194_matte.png
# -rw------- 1 root root  553983 Oct  7  2016 00194.png
# -rw------- 1 root root   30815 Oct  7  2016 00195_matte.png
# -rw------- 1 root root  526919 Oct  7  2016 00195.png
# -rw------- 1 root root   27804 Oct  7  2016 00196_matte.png
# -rw------- 1 root root  547014 Oct  7  2016 00196.png
# -rw------- 1 root root   31006 Oct  7  2016 00197_matte.png
# -rw------- 1 root root  590618 Oct  7  2016 00197.png
# -rw------- 1 root root   30048 Oct  7  2016 00198_matte.png
# -rw------- 1 root root  772332 Oct  7  2016 00198.png
# -rw------- 1 root root   27843 Oct  7  2016 00199_matte.png
# -rw------- 1 root root  654960 Oct  7  2016 00199.png
# -rw------- 1 root root   43540 Oct  7  2016 00200_matte.png
# -rw------- 1 root root  689422 Oct  7  2016 00200.png
# -rw------- 1 root root   40174 Oct  7  2016 00201_matte.png
# -rw------- 1 root root  256611 Oct  7  2016 00201.png
# -rw------- 1 root root   34054 Oct  7  2016 00202_matte.png
# -rw------- 1 root root  783182 Oct  7  2016 00202.png
# -rw------- 1 root root   28981 Oct  7  2016 00203_matte.png
# -rw------- 1 root root  437345 Oct  7  2016 00203.png
# -rw------- 1 root root   27311 Oct  7  2016 00204_matte.png
# -rw------- 1 root root  557341 Oct  7  2016 00204.png
# -rw------- 1 root root   28034 Oct  7  2016 00205_matte.png
# -rw------- 1 root root  578261 Oct  7  2016 00205.png
# -rw------- 1 root root   28721 Oct  7  2016 00206_matte.png
# -rw------- 1 root root  428798 Oct  7  2016 00206.png
# -rw------- 1 root root   23609 Oct  7  2016 00207_matte.png
# -rw------- 1 root root  495236 Oct  7  2016 00207.png
# -rw------- 1 root root   42315 Oct  7  2016 00208_matte.png
# -rw------- 1 root root  238513 Oct  7  2016 00208.png
# -rw------- 1 root root   26886 Oct  7  2016 00209_matte.png
# -rw------- 1 root root  548973 Oct  7  2016 00209.png
# -rw------- 1 root root   37661 Oct  7  2016 00210_matte.png
# -rw------- 1 root root  310427 Oct  7  2016 00210.png
# -rw------- 1 root root   23246 Oct  7  2016 00211_matte.png
# -rw------- 1 root root  559332 Oct  7  2016 00211.png
# -rw------- 1 root root   30450 Oct  7  2016 00212_matte.png
# -rw------- 1 root root  580053 Oct  7  2016 00212.png
# -rw------- 1 root root   14138 Oct  7  2016 00213_matte.png
# -rw------- 1 root root  628653 Oct  7  2016 00213.png
# -rw------- 1 root root   32347 Oct  7  2016 00214_matte.png
# -rw------- 1 root root  506834 Oct  7  2016 00214.png
# -rw------- 1 root root   35500 Oct  7  2016 00215_matte.png
# -rw------- 1 root root  554285 Oct  7  2016 00215.png
# -rw------- 1 root root   27682 Oct  7  2016 00216_matte.png
# -rw------- 1 root root  625423 Oct  7  2016 00216.png
# -rw------- 1 root root   38207 Oct  7  2016 00217_matte.png
# -rw------- 1 root root  463017 Oct  7  2016 00217.png
# -rw------- 1 root root   32747 Oct  7  2016 00218_matte.png
# -rw------- 1 root root  448248 Oct  7  2016 00218.png
# -rw------- 1 root root   29552 Oct  7  2016 00219_matte.png
# -rw------- 1 root root  544361 Oct  7  2016 00219.png
# -rw------- 1 root root   31029 Oct  7  2016 00220_matte.png
# -rw------- 1 root root  601763 Oct  7  2016 00220.png
# -rw------- 1 root root   28168 Oct  7  2016 00221_matte.png
# -rw------- 1 root root  718552 Oct  7  2016 00221.png
# -rw------- 1 root root   44775 Oct  7  2016 00222_matte.png
# -rw------- 1 root root  662834 Oct  7  2016 00222.png
# -rw------- 1 root root   33051 Oct  7  2016 00223_matte.png
# -rw------- 1 root root  600700 Oct  7  2016 00223.png
# -rw------- 1 root root   35441 Oct  7  2016 00224_matte.png
# -rw------- 1 root root  499639 Oct  7  2016 00224.png
# -rw------- 1 root root   25957 Oct  7  2016 00225_matte.png
# -rw------- 1 root root  771901 Oct  7  2016 00225.png
# -rw------- 1 root root   31112 Oct  7  2016 00226_matte.png
# -rw------- 1 root root  528935 Oct  7  2016 00226.png
# -rw------- 1 root root   22903 Oct  7  2016 00227_matte.png
# -rw------- 1 root root  524399 Oct  7  2016 00227.png
# -rw------- 1 root root   41041 Oct  7  2016 00228_matte.png
# -rw------- 1 root root  715623 Oct  7  2016 00228.png
# -rw------- 1 root root   31118 Oct  7  2016 00229_matte.png
# -rw------- 1 root root  727501 Oct  7  2016 00229.png
# -rw------- 1 root root   28011 Oct  7  2016 00230_matte.png
# -rw------- 1 root root  419499 Oct  7  2016 00230.png
# -rw------- 1 root root   24337 Oct  7  2016 00231_matte.png
# -rw------- 1 root root  571338 Oct  7  2016 00231.png
# -rw------- 1 root root   32094 Oct  7  2016 00232_matte.png
# -rw------- 1 root root  641484 Oct  7  2016 00232.png
# -rw------- 1 root root   44632 Oct  7  2016 00233_matte.png
# -rw------- 1 root root  443967 Oct  7  2016 00233.png
# -rw------- 1 root root   28349 Oct  7  2016 00234_matte.png
# -rw------- 1 root root  675843 Oct  7  2016 00234.png
# -rw------- 1 root root   39331 Oct  7  2016 00235_matte.png
# -rw------- 1 root root  468029 Oct  7  2016 00235.png
# -rw------- 1 root root   51816 Oct  7  2016 00236_matte.png
# -rw------- 1 root root  717474 Oct  7  2016 00236.png
# -rw------- 1 root root   39580 Oct  7  2016 00237_matte.png
# -rw------- 1 root root  510228 Oct  7  2016 00237.png
# -rw------- 1 root root   32776 Oct  7  2016 00238_matte.png
# -rw------- 1 root root  526049 Oct  7  2016 00238.png
# -rw------- 1 root root   39447 Oct  7  2016 00239_matte.png
# -rw------- 1 root root  412914 Oct  7  2016 00239.png
# -rw------- 1 root root   45337 Oct  7  2016 00240_matte.png
# -rw------- 1 root root  526811 Oct  7  2016 00240.png
# -rw------- 1 root root   43967 Oct  7  2016 00241_matte.png
# -rw------- 1 root root  419106 Oct  7  2016 00241.png
# -rw------- 1 root root   32213 Oct  7  2016 00242_matte.png
# -rw------- 1 root root  799674 Oct  7  2016 00242.png
# -rw------- 1 root root   41895 Oct  7  2016 00243_matte.png
# -rw------- 1 root root  684877 Oct  7  2016 00243.png
# -rw------- 1 root root   19660 Oct  7  2016 00244_matte.png
# -rw------- 1 root root  525039 Oct  7  2016 00244.png
# -rw------- 1 root root   51632 Oct  7  2016 00245_matte.png
# -rw------- 1 root root  478399 Oct  7  2016 00245.png
# -rw------- 1 root root   26944 Oct  7  2016 00246_matte.png
# -rw------- 1 root root  458173 Oct  7  2016 00246.png
# -rw------- 1 root root   68436 Oct  7  2016 00247_matte.png
# -rw------- 1 root root  595788 Oct  7  2016 00247.png
# -rw------- 1 root root   59661 Oct  7  2016 00248_matte.png
# -rw------- 1 root root  617317 Oct  7  2016 00248.png
# -rw------- 1 root root   36314 Oct  7  2016 00249_matte.png
# -rw------- 1 root root  497897 Oct  7  2016 00249.png
# -rw------- 1 root root   52017 Oct  7  2016 00250_matte.png
# -rw------- 1 root root  569223 Oct  7  2016 00250.png
# -rw------- 1 root root   43026 Oct  7  2016 00251_matte.png
# -rw------- 1 root root  637960 Oct  7  2016 00251.png
# -rw------- 1 root root   30233 Oct  7  2016 00252_matte.png
# -rw------- 1 root root  575121 Oct  7  2016 00252.png
# -rw------- 1 root root   40141 Oct  7  2016 00253_matte.png
# -rw------- 1 root root  559458 Oct  7  2016 00253.png
# -rw------- 1 root root   49282 Oct  7  2016 00254_matte.png
# -rw------- 1 root root  515655 Oct  7  2016 00254.png
# -rw------- 1 root root   28992 Oct  7  2016 00255_matte.png
# -rw------- 1 root root  568896 Oct  7  2016 00255.png
# -rw------- 1 root root   41000 Oct  7  2016 00256_matte.png
# -rw------- 1 root root  447659 Oct  7  2016 00256.png
# -rw------- 1 root root   32613 Oct  7  2016 00257_matte.png
# -rw------- 1 root root  540825 Oct  7  2016 00257.png
# -rw------- 1 root root   20278 Oct  7  2016 00258_matte.png
# -rw------- 1 root root  495523 Oct  7  2016 00258.png
# -rw------- 1 root root   25348 Oct  7  2016 00259_matte.png
# -rw------- 1 root root  707971 Oct  7  2016 00259.png
# -rw------- 1 root root   38452 Oct  7  2016 00260_matte.png
# -rw------- 1 root root  691180 Oct  7  2016 00260.png
# -rw------- 1 root root   43181 Oct  7  2016 00261_matte.png
# -rw------- 1 root root  553864 Oct  7  2016 00261.png
# -rw------- 1 root root   26579 Oct  7  2016 00262_matte.png
# -rw------- 1 root root  578850 Oct  7  2016 00262.png
# -rw------- 1 root root   24670 Oct  7  2016 00263_matte.png
# -rw------- 1 root root  729106 Oct  7  2016 00263.png
# -rw------- 1 root root   22221 Oct  7  2016 00264_matte.png
# -rw------- 1 root root  557074 Oct  7  2016 00264.png
# -rw------- 1 root root   23417 Oct  7  2016 00265_matte.png
# -rw------- 1 root root  978992 Oct  7  2016 00265.png
# -rw------- 1 root root   28153 Oct  7  2016 00266_matte.png
# -rw------- 1 root root  722367 Oct  7  2016 00266.png
# -rw------- 1 root root   42029 Oct  7  2016 00267_matte.png
# -rw------- 1 root root  460573 Oct  7  2016 00267.png
# -rw------- 1 root root   41961 Oct  7  2016 00268_matte.png
# -rw------- 1 root root  762130 Oct  7  2016 00268.png
# -rw------- 1 root root   51466 Oct  7  2016 00269_matte.png
# -rw------- 1 root root  570491 Oct  7  2016 00269.png
# -rw------- 1 root root   41800 Oct  7  2016 00270_matte.png
# -rw------- 1 root root  529093 Oct  7  2016 00270.png
# -rw------- 1 root root   97083 Oct  7  2016 00271_matte.png
# -rw------- 1 root root  702342 Oct  7  2016 00271.png
# -rw------- 1 root root   47010 Oct  7  2016 00272_matte.png
# -rw------- 1 root root  556550 Oct  7  2016 00272.png
# -rw------- 1 root root   30514 Oct  7  2016 00273_matte.png
# -rw------- 1 root root  685971 Oct  7  2016 00273.png
# -rw------- 1 root root   36173 Oct  7  2016 00274_matte.png
# -rw------- 1 root root  717552 Oct  7  2016 00274.png
# -rw------- 1 root root   45937 Oct  7  2016 00275_matte.png
# -rw------- 1 root root  512312 Oct  7  2016 00275.png
# -rw------- 1 root root   31479 Oct  7  2016 00276_matte.png
# -rw------- 1 root root  496292 Oct  7  2016 00276.png
# -rw------- 1 root root   37854 Oct  7  2016 00277_matte.png
# -rw------- 1 root root  624105 Oct  7  2016 00277.png
# -rw------- 1 root root   37169 Oct  7  2016 00278_matte.png
# -rw------- 1 root root  491152 Oct  7  2016 00278.png
# -rw------- 1 root root   33869 Oct  7  2016 00279_matte.png
# -rw------- 1 root root  727764 Oct  7  2016 00279.png
# -rw------- 1 root root   28046 Oct  7  2016 00280_matte.png
# -rw------- 1 root root  557857 Oct  7  2016 00280.png
# -rw------- 1 root root   35640 Oct  7  2016 00281_matte.png
# -rw------- 1 root root  612285 Oct  7  2016 00281.png
# -rw------- 1 root root   48320 Oct  7  2016 00282_matte.png
# -rw------- 1 root root  580388 Oct  7  2016 00282.png
# -rw------- 1 root root   27265 Oct  7  2016 00283_matte.png
# -rw------- 1 root root  544296 Oct  7  2016 00283.png
# -rw------- 1 root root   28121 Oct  7  2016 00284_matte.png
# -rw------- 1 root root  621826 Oct  7  2016 00284.png
# -rw------- 1 root root   31375 Oct  7  2016 00285_matte.png
# -rw------- 1 root root  476982 Oct  7  2016 00285.png
# -rw------- 1 root root   45730 Oct  7  2016 00286_matte.png
# -rw------- 1 root root  661364 Oct  7  2016 00286.png
# -rw------- 1 root root   26416 Oct  7  2016 00287_matte.png
# -rw------- 1 root root  848084 Oct  7  2016 00287.png
# -rw------- 1 root root   61232 Oct  7  2016 00288_matte.png
# -rw------- 1 root root  619399 Oct  7  2016 00288.png
# -rw------- 1 root root   60144 Oct  7  2016 00289_matte.png
# -rw------- 1 root root  582055 Oct  7  2016 00289.png
# -rw------- 1 root root   23660 Oct  7  2016 00290_matte.png
# -rw------- 1 root root  481500 Oct  7  2016 00290.png
# -rw------- 1 root root   51908 Oct  7  2016 00291_matte.png
# -rw------- 1 root root  552728 Oct  7  2016 00291.png
# -rw------- 1 root root   42566 Oct  7  2016 00292_matte.png
# -rw------- 1 root root  533282 Oct  7  2016 00292.png
# -rw------- 1 root root   88116 Oct  7  2016 00293_matte.png
# -rw------- 1 root root  621465 Oct  7  2016 00293.png
# -rw------- 1 root root   44305 Oct  7  2016 00294_matte.png
# -rw------- 1 root root  492551 Oct  7  2016 00294.png
# -rw------- 1 root root   33687 Oct  7  2016 00295_matte.png
# -rw------- 1 root root  575760 Oct  7  2016 00295.png
# -rw------- 1 root root   38603 Oct  7  2016 00296_matte.png
# -rw------- 1 root root  553879 Oct  7  2016 00296.png
# -rw------- 1 root root   43928 Oct  7  2016 00297_matte.png
# -rw------- 1 root root  646161 Oct  7  2016 00297.png
# -rw------- 1 root root   43808 Oct  7  2016 00298_matte.png
# -rw------- 1 root root  636810 Oct  7  2016 00298.png
# -rw------- 1 root root   47819 Oct  7  2016 00299_matte.png
# -rw------- 1 root root  770714 Oct  7  2016 00299.png
# -rw------- 1 root root   34922 Oct  7  2016 00300_matte.png
# -rw------- 1 root root  575126 Oct  7  2016 00300.png

# %% [markdown]
# ### 문제 2. pfcn 데이터 살펴보기

# %%
# 데이터를 np array로 training에서 사람 이미지 한장과 영역 이미지 한장을 불러오는 코드를 작성해주세요. (x, y로 변수 대입)
import glob
import imageio

x = imageio.imread('/gdrive/My Drive/Colab Notebooks/dataset/pfcn_original/training/00002.png')
y = imageio.imread('/gdrive/My Drive/Colab Notebooks/dataset/pfcn_original/training/00002_matte.png')

# %% [markdown]
# ### 문제 3. x와 y의 shape을 출력해보세요.

# %%
# 데이터의 크기를 shape 함수를 통해 출력해주세요.
print(x.shape)
print(y.shape)
# Out:
# (800, 600, 3)
# (800, 600)

# %% [markdown]
# ### 문제 4. x, y를 각각 plt를 통하여 출력하세요.

# %%
# x, y를 plt를 이용하여 출력하는 코드를 작성해보세요.
plt.imshow(x)
plt.colorbar()
plt.show()
plt.imshow(y)
plt.colorbar()
plt.show()

# %% [markdown]
# ### 문제 5. (800, 600)의 의미지는 colab에서 돌리기에 너무 큽니다. (100, 75)로 이미지를 줄여보세요

# %%
# x와 y를 각각 (800, 600, 3) -> (100, 75, 3), (800, 600) -> (100, 75)로 줄이고 plt에서 확인하는 코드를 작성하세요.
from skimage.transform import resize
x1 = resize(x, (100, 75))
y1 = resize(y, (100, 75))

# %%
x1.shape, y1.shape
# Out:
# ((100, 75, 3), (100, 75))

# %% [markdown]
# ### 문제 6 pfcn_small.npz 데이터에서 학습, 테스트 데이터를 로드하세요.

# %%
# 주어진 링크에서 pfcn_small.npz를 다운 받으세요.
#https://drive.google.com/file/d/1_q37TRIFwtwhmSeLu_4h3SkFHrDSjeyl/view?usp=sharing

# !gdown --id 1_q37TRIFwtwhmSeLu_4h3SkFHrDSjeyl
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1_q37TRIFwtwhmSeLu_4h3SkFHrDSjeyl
# From (redirected): https://drive.google.com/uc?id=1_q37TRIFwtwhmSeLu_4h3SkFHrDSjeyl&confirm=t&uuid=c3673db0-2afb-4131-9bf3-ce34992171f5
# To: /content/pfcn_small.npz
# 100% 137M/137M [00:01<00:00, 131MB/s]

# %%
# !ls -al /content/pfcn_small.npz
# Out:
# -rw-r--r-- 1 root root 137288603 Nov 13  2020 /content/pfcn_small.npz

# %%
# pfcn_small.npz에서 train_images, test_images, train_mattes, test_mattes를 np array로 로드하세요.
pfcn_small = np.load('/content/pfcn_small.npz')

# %%
train_images = pfcn_small['train_images']
train_mattes = pfcn_small['train_mattes']
test_images = pfcn_small['test_images']
test_mattes = pfcn_small['test_mattes']

# %% [markdown]
# ### 문제 7. train_images에서 0이 아닌 값들을 출력해보세요.

# %%
# 하나의 이미지에 대한 모든 0이 아닌 값을 출력하는 코드를 작성하세요.
list(filter(lambda x:  x!=0, train_images[0].reshape(-1)))[:10]
# Out:
# [np.float64(0.2362745098039194),
#  np.float64(0.3480392156862709),
#  np.float64(0.6470588235294088),
#  np.float64(0.24509803921568626),
#  np.float64(0.3568627450980406),
#  np.float64(0.6558823529411772),
#  np.float64(0.2549019607843108),
#  np.float64(0.3647058823529383),
#  np.float64(0.6647058823529384),
#  np.float64(0.23725490196078006)]

# %%
train_images[train_images != 0][:10]
# Out:
# array([0.23627451, 0.34803922, 0.64705882, 0.24509804, 0.35686275,
#        0.65588235, 0.25490196, 0.36470588, 0.66470588, 0.2372549 ])

# %% [markdown]
# ### 문제 8. train_images의 dtype을 출력해보세요.

# %%
# dtype을 이용하여 이미지의 np array type을 확인해보세요.
train_images.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Step 2. 전처리

# %% [markdown]
# ### 문제 9. images/mattes 이미지 데이터의 범위 확인

# %%
#  test_images, test_mattes의 shape과 dtype, 0이 아닌 숫자를 출력하는 코드를 작성하세요.
print(train_images.shape)
print(list(filter(lambda x: x != 0, train_images[0:100].reshape(-1)))[:10])
print(train_images.dtype)
print("-------------------")
print(test_images.shape)
print(list(filter(lambda x: x != 0, test_images[0:100].reshape(-1)))[:10])
print(test_images.dtype)
# Out:
# (1700, 100, 75, 3)
# [np.float64(0.2362745098039194), np.float64(0.3480392156862709), np.float64(0.6470588235294088), np.float64(0.24509803921568626), np.float64(0.3568627450980406), np.float64(0.6558823529411772), np.float64(0.2549019607843108), np.float64(0.3647058823529383), np.float64(0.6647058823529384), np.float64(0.23725490196078006)]
# float64
# -------------------
# (300, 100, 75, 3)
# [np.float64(0.5098039215686274), np.float64(0.6411764705882368), np.float64(0.6431372549019636), np.float64(0.5156862745098024), np.float64(0.6470588235294088), np.float64(0.649019607843133), np.float64(0.5382352941176594), np.float64(0.6558823529411887), np.float64(0.6637254901960906), np.float64(0.5284313725490188)]
# float64

# %%
print(train_images.shape)
print(train_images[train_images != 0][:10])
print(train_images.dtype)
print("-------------------")
print(test_images.shape)
print(test_images[test_images != 0][:10])
print(test_images.dtype)
# Out:
# (1700, 100, 75, 3)
# [0.23627451 0.34803922 0.64705882 0.24509804 0.35686275 0.65588235
#  0.25490196 0.36470588 0.66470588 0.2372549 ]
# float64
# -------------------
# (300, 100, 75, 3)
# [0.50980392 0.64117647 0.64313725 0.51568627 0.64705882 0.64901961
#  0.53823529 0.65588235 0.66372549 0.52843137]
# float64

# %% [markdown]
# ### 문제 10. images/mattes 이미지 데이터의 최소/최대값을 출력

# %%
# train/test 전체 데이터에서 각 images, mattes의 min, max를 출력하는 코드를 작성하세요.
print(train_images.max(), train_images.min())
print(test_images.max(), test_images.min())
# Out:
# 1.0 0.0
# 1.0 0.0

# %% [markdown]
# ### 문제 11. mattes의 shape을 (배치, 100, 75, 3)에서 (배치, 100, 75, 1)으로 변경하세요.

# %%
from skimage import color
train_mattes = train_mattes.reshape(train_mattes.shape[0], 100, 75, 1)
test_mattes = test_mattes.reshape(test_mattes.shape[0], 100, 75, 1)
train_mattes.shape, test_mattes.shape
# Out:
# ((1700, 100, 75, 1), (300, 100, 75, 1))

# %% [markdown]
# ## Step 3. 시각화 방법

# %% [markdown]
# ### 문제 12. train_image의 이미지를 5장 획득하여 (5, 100, 75, 3)의 shape을 출력하세요.

# %%
# (배치, 100, 75, 3)인 train_images에서 (5, 100, 75, 3)을 획득하는 코드를 작성하세요.
train_images[:5].shape
# Out:
# (5, 100, 75, 3)

# %% [markdown]
# ### 문제 13. 획득한 5장의 의미지를 (100, 75 * 5, 3)의 shape으로 변경해보세요.

# %%
# np.hstack은 height 방향의 배열을 풀어서 width 방향으로 연결해줍니다.
# 해당 기능을 쓰면 (height, image_height, image_width, color)의 shape을 (image_height, image_width * height, color)으로 바꿔 줄 수 있습니다.
# 코드를 작성해보세요.
np.hstack(train_images[:5]).shape
# Out:
# (100, 375, 3)

# %%
# transpose는 tensor의 axis를 섞는 기능을 합니다.
# 해당 기능을 이용해서 (100, 375, 3)을 작성하는 코드를 작성해보세요.
train_images[:5].transpose([1, 0, 2, 3]).reshape((100, -1 ,3)).shape
# Out:
# (100, 375, 3)

# %% [markdown]
# ### 문제 14. (100, 375, 3)이 된 tensor를 plt로 출력해보세요.

# %%
# (28, 140, 3)의 이미지를 plt로 출력해보세요.
plt.imshow(train_images[:5].transpose([1, 0, 2, 3]).reshape((100, -1 ,3)))
plt.show()

# %% [markdown]
# ### 문제 15. mettes도 (100, 375)으로 plt로 출력해보세요.

# %%
# (28, 140, 1)의 이미지를 plt로 출력해보세요.
plt.imshow(train_mattes[:5].transpose([1, 0, 2, 3]).reshape((100, -1)), cmap="gray")
plt.show()

# %% [markdown]
# ## Step 4. AE 모델링

# %% [markdown]
# ### 문제 16. 해당 학습셋을 처리하는 이미지 segmentation 모델을 작성하세요.

# %%
# input (100, 75, 3), output (100, 75, 1)을 처리할 수 있는 모래시계 모양의 모델을 작성하세요.
from keras.layers import Dense, Input, Conv2D, UpSampling2D, Flatten, Reshape
from keras.models import Model

def ae_like():
  inputs = Input((100, 75, 3))
  x = Conv2D(32, 3, 2, activation='relu', padding='same')(inputs)
  x = Conv2D(64, 3, 2, activation='relu', padding='same')(x)
  x = Conv2D(128, 3, 2, activation='relu', padding='same')(x)
  x = Flatten()(x)
  latent = Dense(10)(x)

  x = Dense((13 * 10 * 128))(latent)
  x = Reshape((13, 10, 128))(x)

  x = UpSampling2D(size = (2,2))(x)
  x = Conv2D(128, (2,2), (1,1), activation='relu', padding='valid')(x)

  x = UpSampling2D(size = (2,2))(x)
  x = Conv2D(64, (1,1), (1,1), activation='relu', padding='valid')(x)

  x = UpSampling2D(size = (2,2))(x)
  x = Conv2D(32, (1,2), (1,1), activation='relu', padding='valid')(x)

  x = Conv2D(1, (1,1), (1,1), activation='sigmoid')(x)


  model = Model(inputs, x)
  return model

# %% [markdown]
# ### 문제 17. 모델을 할당 받고 서머리를 출력해보세요.

# %%
# ae_like() 모델을 할당 받고 서머리를 출력하는 코드를 작성하세요.
model = ae_like()
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 100, 75, 3)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 50, 38, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 25, 19, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 13, 10, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 16640)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │       166,410 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16640)          │       183,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 13, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 26, 20, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 25, 19, 128)    │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 50, 38, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 50, 38, 64)     │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_2 (UpSampling2D)  │ (None, 100, 76, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 100, 75, 32)    │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 100, 75, 1)     │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 520,779 (1.99 MB)
#  Trainable params: 520,779 (1.99 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 문제 18. 만든 모델에 로스와 옵티마이저, 메트릭을 설정하세요.

# %%
# 만든 모델에 loss는 mse, optimizer는 adam 매트릭은 accuracy으로 설정하는 코드를 작성하세요.
model.compile(loss="mse", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# ### 문제 19. 만든 모델에 train_images를 학습시켜 보세요.

# %%
# train_images 학습시키고 25 epochs을 돌리고 그 진행 사항을 hist에 저장하는 코드를 작성하세요.
hist = model.fit(train_images, train_mattes, validation_data=(test_images, test_mattes), epochs=25, verbose=1)
# Out:
# Epoch 1/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 16s 133ms/step - accuracy: 0.6986 - loss: 0.1689 - val_accuracy: 0.7625 - val_loss: 0.1249
# Epoch 2/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7626 - loss: 0.1255 - val_accuracy: 0.7523 - val_loss: 0.1260
# Epoch 3/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7732 - loss: 0.1163 - val_accuracy: 0.7954 - val_loss: 0.0996
# Epoch 4/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8067 - loss: 0.0943 - val_accuracy: 0.8156 - val_loss: 0.0847
# Epoch 5/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8211 - loss: 0.0834 - val_accuracy: 0.8206 - val_loss: 0.0819
# Epoch 6/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8263 - loss: 0.0801 - val_accuracy: 0.8241 - val_loss: 0.0787
# Epoch 7/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8391 - loss: 0.0701 - val_accuracy: 0.8299 - val_loss: 0.0739
# Epoch 8/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8478 - loss: 0.0631 - val_accuracy: 0.8376 - val_loss: 0.0693
# Epoch 9/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8577 - loss: 0.0551 - val_accuracy: 0.8374 - val_loss: 0.0703
# Epoch 10/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8648 - loss: 0.0499 - val_accuracy: 0.8380 - val_loss: 0.0695
# Epoch 11/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8722 - loss: 0.0438 - val_accuracy: 0.8434 - val_loss: 0.0656
# Epoch 12/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8788 - loss: 0.0384 - val_accuracy: 0.8440 - val_loss: 0.0658
# Epoch 13/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8839 - loss: 0.0341 - val_accuracy: 0.8436 - val_loss: 0.0666
# Epoch 14/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8874 - loss: 0.0314 - val_accuracy: 0.8418 - val_loss: 0.0683
# Epoch 15/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8890 - loss: 0.0294 - val_accuracy: 0.8438 - val_loss: 0.0677
# Epoch 16/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8911 - loss: 0.0272 - val_accuracy: 0.8420 - val_loss: 0.0694
# Epoch 17/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8926 - loss: 0.0259 - val_accuracy: 0.8435 - val_loss: 0.0695
# Epoch 18/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8963 - loss: 0.0238 - val_accuracy: 0.8405 - val_loss: 0.0723
# Epoch 19/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8955 - loss: 0.0234 - val_accuracy: 0.8429 - val_loss: 0.0711
# Epoch 20/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8963 - loss: 0.0224 - val_accuracy: 0.8425 - val_loss: 0.0708
# Epoch 21/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8965 - loss: 0.0220 - val_accuracy: 0.8449 - val_loss: 0.0695
# Epoch 22/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8975 - loss: 0.0216 - val_accuracy: 0.8432 - val_loss: 0.0713
# Epoch 23/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8975 - loss: 0.0210 - val_accuracy: 0.8420 - val_loss: 0.0724
# Epoch 24/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8988 - loss: 0.0204 - val_accuracy: 0.8427 - val_loss: 0.0719
# Epoch 25/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8992 - loss: 0.0199 - val_accuracy: 0.8441 - val_loss: 0.0717

# %% [markdown]
# ### 문제 20. 학습 진행 사항을 plt으로 출력하세요.

# %%
# hist의 accuracy plt의 plot을 이용하여 출력하는 코드를 작성하세요.
plt.plot(hist.history['accuracy'], label = "accuracy")
plt.plot(hist.history['loss'], label = "loss")
plt.plot(hist.history['val_accuracy'], label = "val_accuracy")
plt.plot(hist.history['val_loss'], label = "val_loss")
plt.legend(loc = "upper left")
plt.show()

# %% [markdown]
# ## Step 5. 결과 확인

# %% [markdown]
# ### 문제 21. 완성된 모델에서 test_image를 1장 넣고 결과를 res 변수에 저정하세요.

# %%
# 모델에 test_mages 중 1장을 넣고 결과를 받는 코드를 작성하세요.
res = model.predict( test_images[0:1] )
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 929ms/step

# %% [markdown]
# ### 문제 22. res, test_mattes[1]를 width 방향으로 결합하여 plt로 출력하세요.

# %%
# res, test_mattes[1]를 width 방향으로 결합하여 (100, 75 * 3, 1) 의 이미지를 만들어 plt로 출력하는 코드를 작성하세요.

plt.imshow( np.concatenate([res[0], test_mattes[0]]).reshape((2, -1, 75, 1)).transpose([1, 0, 2, 3]).reshape((100, -1)), cmap="gray")
plt.show()

# %% [markdown]
# ### 문제 23. res에 0.5의 값을 기준으로 0과 1로 2원화 시키고 다시 문제 22처럼 출력해보세요.

# %%
# res를 0.5기준으로 0,1의 값으로 이원화 시킨 뒤 문제 22처럼 출력하는 코드를 작성하세요.
plt.imshow( np.concatenate([(res[0] > 0.5).astype(np.float64), test_mattes[0]]).reshape((2, -1, 75, 1)).transpose([1, 0, 2, 3]).reshape((100, -1)), cmap="gray")
plt.show()

# %% [markdown]
# ### 문제 24. 5장의 test_images를 모델에 넣은 뒤 결과를 문제 22 방식으로 비교하세요.

# %%
# 5장의 이미지를 모델에 넣고 결과를 22번과 같은 방식으로 비교하는 코드를 작성하세요

five = (model.predict(test_images[:5]) > 0.5).astype(np.float64)
plt.imshow( np.concatenate([five , test_mattes[:5]], axis=2).transpose((1, 0, 2, 3)).reshape(100, -1) , cmap="gray")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
plt.imshow(test_images[:5].transpose((1, 0, 2, 3)).reshape((100, -1, 3)))
plt.show()

# %% [markdown]
# ### 문제 25. test_images[1]과 res를 곱한뒤 plt에 출력해보세요.

# %%
# 예측 이미지와 원본이미지를 곱하여 배경을 지워보세요

plt.imshow ( five[2].reshape((100, 75, 1)) * test_images[2]  )
plt.show()

# %% [markdown]
# ## Step 6. U-net 모델링

# %% [markdown]
# ### 문제 26. 해당 학습셋을 처리하는 이미지 segmentation 모델을 작성하세요.

# %%
# input (100, 75, 3), output (100, 75, 1)을 처리할 수 있는 모래시계 모양의 모델을 작성하세요.
from keras.layers import Dense, Input, Conv2D, Conv2DTranspose, Flatten, Reshape, ZeroPadding2D
from keras.models import Model
from keras.layers import BatchNormalization, Dropout, Activation, MaxPool2D, concatenate

def conv2d_block(x, channel):
  x = Conv2D(channel, 3, padding="same")(x)
  x = BatchNormalization()(x)
  x = Activation("relu")(x)

  x = Conv2D(channel, 3, padding="same")(x)
  x = BatchNormalization()(x)
  x = Activation("relu")(x)
  return x

def unet_like():
  inputs = Input((100, 75, 3))

  c1 = conv2d_block(inputs, 16)
  p1 = MaxPool2D((2,2))(c1)
  p1 = Dropout(0.1)(p1)

  c2 = conv2d_block(p1, 32)
  p2 = MaxPool2D((2,2))(c2)
  p2 = Dropout(0.1)(p2)

  c3 = conv2d_block(p2, 64)
  p3 = MaxPool2D((2,2))(c3)
  p3 = Dropout(0.1)(p3)

  c4 = conv2d_block(p3, 128)
  p4 = MaxPool2D((2,2))(c4)
  p4 = Dropout(0.1)(p4)

  c5 = conv2d_block(p4, 256)

  u6 = Conv2DTranspose(128, 2, 2, padding='valid')(c5)
  u6 = ZeroPadding2D(padding=((0,0),(0,1)))(u6)
  u6 = concatenate([u6, c4])
  u6 = Dropout(0.1)(u6)
  c6 = conv2d_block(u6, 128)

  u7 = Conv2DTranspose(64, 2, 2, padding='valid')(c6)
  u7 = ZeroPadding2D(padding=((0,1),(0,0)))(u7)
  u7 = concatenate([u7, c3])
  u7 = Dropout(0.1)(u7)
  c7 = conv2d_block(u7, 64)

  u8 = Conv2DTranspose(32, 2, 2, padding='valid')(c7)
  u8 = ZeroPadding2D(padding=((0,0),(0,1)))(u8)
  u8 = concatenate([u8, c2])
  u8 = Dropout(0.1)(u8)
  c8 = conv2d_block(u8, 32)

  u9 = Conv2DTranspose(16, 2, 2, padding='valid')(c8)
  u9 = ZeroPadding2D(padding=((0,0),(0,1)))(u9)
  u9 = concatenate([u9, c1])
  u9 = Dropout(0.1)(u9)
  c9 = conv2d_block(u9, 16)

  outputs = Conv2D(1, (1,1), activation="sigmoid")(c9)

  model = Model(inputs, outputs)
  return model

# %% [markdown]
# ### 문제 27. 모델을 할당 받고 서머리를 출력해보세요.

# %%
# unet_like() 모델을 할당 받고 서머리를 출력하는 코드를 작성하세요.
model = unet_like()
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 100, 75,   │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 100, 75,   │        448 │ input_layer_2[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100, 75,   │         64 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 100, 75,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 100, 75,   │      2,320 │ activation_10[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100, 75,   │         64 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 100, 75,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 50, 37,    │          0 │ activation_11[0]… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 50, 37,    │          0 │ max_pooling2d_4[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 50, 37,    │      4,640 │ dropout_4[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 50, 37,    │        128 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 50, 37,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 50, 37,    │      9,248 │ activation_12[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 50, 37,    │        128 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 50, 37,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 25, 18,    │          0 │ activation_13[0]… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 25, 18,    │          0 │ max_pooling2d_5[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 25, 18,    │     18,496 │ dropout_5[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 25, 18,    │        256 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 25, 18,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 25, 18,    │     36,928 │ activation_14[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 25, 18,    │        256 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 25, 18,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 12, 9, 64) │          0 │ activation_15[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 12, 9, 64) │          0 │ max_pooling2d_6[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 12, 9,     │     73,856 │ dropout_6[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 9,     │        512 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 12, 9,     │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 12, 9,     │    147,584 │ activation_16[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 9,     │        512 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 12, 9,     │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 6, 4, 128) │          0 │ activation_17[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 6, 4, 128) │          0 │ max_pooling2d_7[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 6, 4, 256) │    295,168 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 4, 256) │      1,024 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 6, 4, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 6, 4, 256) │    590,080 │ activation_18[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 4, 256) │      1,024 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 6, 4, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 12, 8,     │    131,200 │ activation_19[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d      │ (None, 12, 9,     │          0 │ conv2d_transpose… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 12, 9,     │          0 │ zero_padding2d[0… │
# │ (Concatenate)       │ 256)              │            │ activation_17[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 12, 9,     │          0 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 12, 9,     │    295,040 │ dropout_8[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 9,     │        512 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 12, 9,     │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 12, 9,     │    147,584 │ activation_20[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 9,     │        512 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 12, 9,     │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 24, 18,    │     32,832 │ activation_21[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1    │ (None, 25, 18,    │          0 │ conv2d_transpose… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 25, 18,    │          0 │ zero_padding2d_1… │
# │ (Concatenate)       │ 128)              │            │ activation_15[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 25, 18,    │          0 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 25, 18,    │     73,792 │ dropout_9[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 25, 18,    │        256 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 25, 18,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 25, 18,    │     36,928 │ activation_22[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 25, 18,    │        256 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 25, 18,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 50, 36,    │      8,224 │ activation_23[0]… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_2    │ (None, 50, 37,    │          0 │ conv2d_transpose… │
# │ (ZeroPadding2D)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 50, 37,    │          0 │ zero_padding2d_2… │
# │ (Concatenate)       │ 64)               │            │ activation_13[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 50, 37,    │          0 │ concatenate_2[0]… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 50, 37,    │     18,464 │ dropout_10[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 50, 37,    │        128 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 50, 37,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 50, 37,    │      9,248 │ activation_24[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 50, 37,    │        128 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 50, 37,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 100, 74,   │      2,064 │ activation_25[0]… │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_3    │ (None, 100, 75,   │          0 │ conv2d_transpose… │
# │ (ZeroPadding2D)     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 100, 75,   │          0 │ zero_padding2d_3… │
# │ (Concatenate)       │ 32)               │            │ activation_11[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 100, 75,   │          0 │ concatenate_3[0]… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 100, 75,   │      4,624 │ dropout_11[0][0]  │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100, 75,   │         64 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 100, 75,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 100, 75,   │      2,320 │ activation_26[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100, 75,   │         64 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 100, 75,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 100, 75,   │         17 │ activation_27[0]… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,946,993 (7.43 MB)
#  Trainable params: 1,944,049 (7.42 MB)
#  Non-trainable params: 2,944 (11.50 KB)

# %% [markdown]
# ### 문제 28. 만든 모델에 로스와 옵티마이저, 메트릭을 설정하세요.

# %%
# 만든 모델에 loss는 mse, optimizer는 adam 매트릭은 accuracy으로 설정하는 코드를 작성하세요.
model.compile(loss="mse", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# ### 문제 29. 만든 모델에 train_noisy_images를 학습시켜 보세요.

# %%
# train_images 학습시키고 25 epochs을 돌리고 그 진행 사항을 hist에 저장하는 코드를 작성하세요.
hist = model.fit(train_images, train_mattes, validation_data=(test_images, test_mattes), epochs=25, verbose=1)
# Out:
# Epoch 1/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 50s 416ms/step - accuracy: 0.7293 - loss: 0.1417 - val_accuracy: 0.5625 - val_loss: 0.3286
# Epoch 2/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8519 - loss: 0.0590 - val_accuracy: 0.7407 - val_loss: 0.1506
# Epoch 3/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8696 - loss: 0.0443 - val_accuracy: 0.7500 - val_loss: 0.1385
# Epoch 4/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8725 - loss: 0.0400 - val_accuracy: 0.7636 - val_loss: 0.1193
# Epoch 5/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8795 - loss: 0.0347 - val_accuracy: 0.8110 - val_loss: 0.0904
# Epoch 6/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8792 - loss: 0.0333 - val_accuracy: 0.8429 - val_loss: 0.0631
# Epoch 7/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8853 - loss: 0.0280 - val_accuracy: 0.8481 - val_loss: 0.0619
# Epoch 8/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8831 - loss: 0.0297 - val_accuracy: 0.8692 - val_loss: 0.0407
# Epoch 9/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8897 - loss: 0.0234 - val_accuracy: 0.8760 - val_loss: 0.0353
# Epoch 10/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8921 - loss: 0.0213 - val_accuracy: 0.8769 - val_loss: 0.0335
# Epoch 11/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8930 - loss: 0.0213 - val_accuracy: 0.8759 - val_loss: 0.0344
# Epoch 12/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8955 - loss: 0.0182 - val_accuracy: 0.8846 - val_loss: 0.0258
# Epoch 13/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8947 - loss: 0.0185 - val_accuracy: 0.8775 - val_loss: 0.0332
# Epoch 14/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8917 - loss: 0.0217 - val_accuracy: 0.8662 - val_loss: 0.0415
# Epoch 15/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8967 - loss: 0.0172 - val_accuracy: 0.8843 - val_loss: 0.0264
# Epoch 16/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8983 - loss: 0.0159 - val_accuracy: 0.8836 - val_loss: 0.0263
# Epoch 17/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8962 - loss: 0.0168 - val_accuracy: 0.8807 - val_loss: 0.0304
# Epoch 18/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8995 - loss: 0.0147 - val_accuracy: 0.8870 - val_loss: 0.0237
# Epoch 19/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9000 - loss: 0.0136 - val_accuracy: 0.8846 - val_loss: 0.0255
# Epoch 20/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8976 - loss: 0.0156 - val_accuracy: 0.8861 - val_loss: 0.0243
# Epoch 21/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9008 - loss: 0.0124 - val_accuracy: 0.8861 - val_loss: 0.0242
# Epoch 22/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8980 - loss: 0.0146 - val_accuracy: 0.8879 - val_loss: 0.0220
# Epoch 23/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9014 - loss: 0.0121 - val_accuracy: 0.8870 - val_loss: 0.0229
# Epoch 24/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9021 - loss: 0.0113 - val_accuracy: 0.8837 - val_loss: 0.0266
# Epoch 25/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8975 - loss: 0.0160 - val_accuracy: 0.8849 - val_loss: 0.0263

# %% [markdown]
# ### 문제 30. 학습 진행 사항을 plt으로 출력하세요.

# %%
# hist의 accuracy plt의 plot을 이용하여 출력하는 코드를 작성하세요.
plt.plot(hist.history['accuracy'], label = "accuracy")
plt.plot(hist.history['loss'], label = "loss")
plt.plot(hist.history['val_accuracy'], label = "val_accuracy")
plt.plot(hist.history['val_loss'], label = "val_loss")
plt.legend(loc = "upper left")
plt.show()

# %% [markdown]
# ## Step 7. 결과 확인

# %% [markdown]
# ### 문제 31. 완성된 모델에서 test_image를 1장 넣고 결과를 res 변수에 저정하세요.

# %%
# 모델에 test_mages 중 1장을 넣고 결과를 받는 코드를 작성하세요.
res = model.predict( test_images[2:3] )
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %% [markdown]
# ### 문제 32. test_images[1], test_mattes[1]를 width 방향으로 결합하여 plt로 출력하세요.

# %%
# test_mattes[1]를 width 방향으로 결합하여 (100, 75 * 3, 1) 의 이미지를 만들어 plt로 출력하는 코드를 작성하세요.
imgs = np.concatenate([res.reshape((100, 75, 1)), test_mattes[2]]).reshape((2, -1, 75, 1)).transpose((1,0, 2, 3)).reshape((100, -1))
plt.imshow(imgs, cmap="gray")
plt.show()

# %% [markdown]
# ### 문제 33. res에 0.5의 값을 기준으로 0과 1로 2원화 시키고 다시 문제 32처럼 출력해보세요.

# %%
# res를 0.5기준으로 0,1의 값으로 이원화 시킨 뒤 문제 32처럼 출력하는 코드를 작성하세요.
imgs = np.concatenate([(res > 0.5).astype(np.float64).reshape((100, 75, 1)), test_mattes[2] ]).reshape((2, -1, 75, 1)).transpose((1,0, 2, 3)).reshape((100, -1))
plt.imshow(imgs, cmap="gray")
plt.show()

# %% [markdown]
# ### 문제 34. 5장의 test_images를 모델에 넣은 뒤 결과를 문제 32 방식으로 비교하세요.

# %%
# 5장의 이미지를 모델에 넣고 결과를 32번과 같은 방식으로 비교하는 코드를 작성하세요
five = (model.predict(test_images[:5]) > 0.5).astype(np.float64)
plt.imshow( np.concatenate([five , test_mattes[:5]], axis=2).transpose((1, 0, 2, 3)).reshape(100, -1) , cmap="gray")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
plt.imshow(test_images[:5].transpose((1,0, 2, 3)).reshape((100, -1, 3)))
plt.show()

# %% [markdown]
# ### 문제 35. test_images[1]과 res를 곱한뒤 plt에 출력해보세요.

# %%
# 예측 이미지와 원본이미지를 곱하여 배경을 지워보세요
plt.imshow(test_images[4] * test_mattes[4].reshape((100, 75 ,1)))
plt.show()

# %%
plt.imshow(test_images[4] * model.predict(test_images[4:5]).reshape((100, 75 ,1)))
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step

# %% [markdown]
# ## Step 8. 모델 저장 및 로드, 다운

# %% [markdown]
# ### 문제 36. 모델을 저장하세요.

# %%
# 모델을 저장하는 코드를 작성하세요.
model.save("./lecture003.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# !ls -al /content
# Out:
# total 157212
# drwxr-xr-x 1 root root      4096 Mar  8 05:39 .
# drwxr-xr-x 1 root root      4096 Mar  8 05:24 ..
# drwxr-xr-x 4 root root      4096 Feb  6 14:31 .config
# -rw-r--r-- 1 root root  23673536 Mar  8 05:39 lecture003.h5
# -rw-r--r-- 1 root root 137288603 Nov 13  2020 pfcn_small.npz
# drwxr-xr-x 1 root root      4096 Feb  6 14:31 sample_data

# %% [markdown]
# ### 문제 37. 모델 파일을 새로운 모델에 로드하세요.

# %%
# 모델을 로드하는 코드를 작성하세요.
new_model = tf.keras.models.load_model("./lecture003.h5", custom_objects={'mse': tf.keras.metrics.MeanSquaredError()})
new_model.summary()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 100, 75,   │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 100, 75,   │        448 │ input_layer_2[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100, 75,   │         64 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 100, 75,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 100, 75,   │      2,320 │ activation_10[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100, 75,   │         64 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 100, 75,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 50, 37,    │          0 │ activation_11[0]… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 50, 37,    │          0 │ max_pooling2d_4[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 50, 37,    │      4,640 │ dropout_4[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 50, 37,    │        128 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 50, 37,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 50, 37,    │      9,248 │ activation_12[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 50, 37,    │        128 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 50, 37,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 25, 18,    │          0 │ activation_13[0]… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 25, 18,    │          0 │ max_pooling2d_5[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 25, 18,    │     18,496 │ dropout_5[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 25, 18,    │        256 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 25, 18,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 25, 18,    │     36,928 │ activation_14[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 25, 18,    │        256 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 25, 18,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 12, 9, 64) │          0 │ activation_15[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 12, 9, 64) │          0 │ max_pooling2d_6[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 12, 9,     │     73,856 │ dropout_6[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 9,     │        512 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 12, 9,     │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 12, 9,     │    147,584 │ activation_16[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 9,     │        512 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 12, 9,     │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 6, 4, 128) │          0 │ activation_17[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 6, 4, 128) │          0 │ max_pooling2d_7[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 6, 4, 256) │    295,168 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 4, 256) │      1,024 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 6, 4, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 6, 4, 256) │    590,080 │ activation_18[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 4, 256) │      1,024 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 6, 4, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 12, 8,     │    131,200 │ activation_19[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d      │ (None, 12, 9,     │          0 │ conv2d_transpose… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 12, 9,     │          0 │ zero_padding2d[0… │
# │ (Concatenate)       │ 256)              │            │ activation_17[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 12, 9,     │          0 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 12, 9,     │    295,040 │ dropout_8[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 9,     │        512 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 12, 9,     │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 12, 9,     │    147,584 │ activation_20[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 9,     │        512 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 12, 9,     │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 24, 18,    │     32,832 │ activation_21[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1    │ (None, 25, 18,    │          0 │ conv2d_transpose… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 25, 18,    │          0 │ zero_padding2d_1… │
# │ (Concatenate)       │ 128)              │            │ activation_15[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 25, 18,    │          0 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 25, 18,    │     73,792 │ dropout_9[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 25, 18,    │        256 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 25, 18,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 25, 18,    │     36,928 │ activation_22[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 25, 18,    │        256 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 25, 18,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 50, 36,    │      8,224 │ activation_23[0]… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_2    │ (None, 50, 37,    │          0 │ conv2d_transpose… │
# │ (ZeroPadding2D)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 50, 37,    │          0 │ zero_padding2d_2… │
# │ (Concatenate)       │ 64)               │            │ activation_13[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 50, 37,    │          0 │ concatenate_2[0]… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 50, 37,    │     18,464 │ dropout_10[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 50, 37,    │        128 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 50, 37,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 50, 37,    │      9,248 │ activation_24[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 50, 37,    │        128 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 50, 37,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 100, 74,   │      2,064 │ activation_25[0]… │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_3    │ (None, 100, 75,   │          0 │ conv2d_transpose… │
# │ (ZeroPadding2D)     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 100, 75,   │          0 │ zero_padding2d_3… │
# │ (Concatenate)       │ 32)               │            │ activation_11[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 100, 75,   │          0 │ concatenate_3[0]… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 100, 75,   │      4,624 │ dropout_11[0][0]  │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100, 75,   │         64 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 100, 75,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 100, 75,   │      2,320 │ activation_26[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100, 75,   │         64 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 100, 75,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 100, 75,   │         17 │ activation_27[0]… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,946,995 (7.43 MB)
#  Trainable params: 1,944,049 (7.42 MB)
#  Non-trainable params: 2,944 (11.50 KB)
#  Optimizer params: 2 (12.00 B)

# %% [markdown]
# ### 문제 38. 로드한 모델을 test 데이터로 평가해보세요.

# %%
# 로드한 모델을 test 데이터로 평가해보세요.
loss, acc = model.evaluate(test_images, test_mattes, verbose=1)
print(loss, acc)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8891 - loss: 0.0264
# 0.02631712704896927 0.8848782181739807

# %%
loss, acc = new_model.evaluate(test_images, test_mattes, verbose=1)
print(loss, acc)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - accuracy: 0.8891 - loss: 0.0263
# 0.02646740898489952 0.8848782181739807

# %% [markdown]
# ### 문제 39. 모델을 내 컴퓨터에 저장해보세요

# %%
# 모델을 내 컴퓨터에 저장해보세요.
from google.colab import files
files.download("./lecture003.h5")
